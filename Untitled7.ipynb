# %% [markdown]
# <a href="https://colab.research.google.com/github/shrutigaurav712004-ops/codeAlpha_task/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 1
# Hangman Game

import random

words = ["python", "coding", "alpha", "intern", "program"]

word = random.choice(words)
display = ["_"] * len(word)
guessed_letters = []
attempts = 6

print("Welcome to Hangman Game!")

while attempts > 0 and "_" in display:
    print("\nWord:", " ".join(display))
    print("Remaining attempts:", attempts)

    guess = input("Guess a letter: ").lower()

    if guess in guessed_letters:
        print("You already guessed this letter.")
        continue

    guessed_letters.append(guess)

    if guess in word:
        print("Correct guess!")
        for i in range(len(word)):
            if word[i] == guess:
                display[i] = guess
    else:
        print("Wrong guess!")
        attempts -= 1

if "_" not in display:
    print("\nCongratulations! You guessed the word:", word)
else:
    print("\nGame Over! The correct word was:", word)
# Out:
# Welcome to Hangman Game!
#
# Word: _ _ _ _ _ _
# Remaining attempts: 6
# Guess a letter: p
# Wrong guess!
#
# Word: _ _ _ _ _ _
# Remaining attempts: 5
# Guess a letter: t
# Correct guess!
#
# Word: _ _ t _ _ _
# Remaining attempts: 5
# Guess a letter: a
# Wrong guess!
#
# Word: _ _ t _ _ _
# Remaining attempts: 4
# Guess a letter: t
# You already guessed this letter.
#
# Word: _ _ t _ _ _
# Remaining attempts: 4
# Guess a letter: n
# Correct guess!
#
# Word: _ n t _ _ n
# Remaining attempts: 4
# Guess a letter: f
# Wrong guess!
#
# Word: _ n t _ _ n
# Remaining attempts: 3
# Guess a letter: s
# Wrong guess!
#
# Word: _ n t _ _ n
# Remaining attempts: 2
# Guess a letter: p
# You already guessed this letter.
#
# Word: _ n t _ _ n
# Remaining attempts: 2
# Guess a letter: y
# Wrong guess!
#
# Word: _ n t _ _ n
# Remaining attempts: 1
# Guess a letter: h
# Wrong guess!
#
# Game Over! The correct word was: intern
